# %% [markdown]
# <h1><b><center>From MATLAB to Python for GeoidLab</center></b></h1>
# <p style="text-align: center; font-size: 1.2em; color: white;">
#     Author: Caleb Kelly<br>
# </p>

# %%
import sys
sys.path.append('../src')
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

from scipy.io import loadmat, savemat

from geoidlab.utils import matlab_io

# %%
fname = '/Users/kelly/Documents/Github/easy-pygeoid/MATLAB/RTM/DTMZ.mat'

# %%
mat_io = matlab_io.MATLABIO(fname)

# %%
mat_io.read_mat(to_xarray=True)
# Out:
# <xarray.Dataset> Size: 18MB
# Dimensions:  (lat: 1201, lon: 961)
# Coordinates:
#   * lat      (lat) float64 10kB 3.0 3.008 3.017 3.025 ... 12.97 12.98 12.99 13.0
#   * lon      (lon) float64 8kB -5.0 -4.992 -4.983 -4.975 ... 2.983 2.992 3.0
# Data variables:
#     grid1    (lat, lon) float64 9MB -4.383e+03 -4.392e+03 ... 225.0 223.5
#     grid2    (lat, lon) float64 9MB -4.437e+03 -4.437e+03 ... 239.8 239.7

# %%
fname = '/Users/kelly/Documents/Academics/PhD/Chapter 6/VCD/Mat files/vcd.mat'
mat_io = matlab_io.MATIO(fname)
mat_io.read_mat(to_xarray=False)
